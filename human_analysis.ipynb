# %%
#%% Transitive Inference - Human behavioral data analysis  #########################

from __future__ import division
import numpy as np
import matplotlib as mpl
import sys

# local #
import task_train_test      as tk
import nn_models            as nm
import nn_plot_functions    as npf
import nn_analyses          as nna
import ti_functions         as ti
import postproc             as pp
import behavior_functions   as bf
import pandas               as pd

datadir         = 'human_data/'   # directory of data and (saved analysis file)
loadfile        = 1               # 1: load analysis file (if available), 0: calculate analysis file

# %%
# %% Analyze or load saved analysis ###
currentdir      = %pwd
jobname         = '%s/%s' % (currentdir,datadir)
sys.path.insert(0, sys.path[0] + jobname)
from init import singleout
p = singleout()
taskfunc       = tk.Get_taskfunc(p)    
filestring = '%s/%ssaved_analysis' % (currentdir,datadir)
if loadfile == 0:           # c
    sys.path.insert(0, sys.path[0] + jobname)
    Behaviors, Data = ti.Behavior_across_humans( jobname )
    Debrief         = ti.Debrief_across_humans(  jobname )
    tk.writefile(filestring,[Behaviors,Data,Debrief])       
else:
    Behaviors, Data, _ = tk.readfile(filestring)
    Debrief            = ti.Debrief_across_humans(jobname)
# Out:
# Reading file (pickle) /Users/kendrick/emergent_transitive/human_data/saved_analysis.p...
# ---- 394 total human subjects ----
# (/Users/kendrick/emergent_transitive/human_data/ti0/) Behavioral plots, Human study

# %%
# Select Subjects #
NO_RESPONSE     = 20   # Max number of allowed no-response trials (above which exclude the subject)
TRAIN_FINAL     = .5   # Minimum proportion correct on Training trials
TRAIN           = 0    
TEST            = 1
COHORTS         = ['cohort_1','cohort_2']
TIDs_plot, str  = ti.Select_Human_Subjects(p, Behaviors, TRAIN_FINAL, TRAIN, TEST, NO_RESPONSE, COHORTS)
# Out:
# (['cohort_1', 'cohort_2']) Selecting subjects: 294 of 394 (75%) meet performance/response criteria

# %%
# Plot summary of performance across task blocks #
mpl.use("Qt5Agg") # set the backend 
ti.Human_Performance(p, Behaviors, TIDs_plot, str)
# Out:
# (cohort_2) 1st Critical : 151 of 294 subjects (51%) (p = 0.000213912, Binomial)
# (cohort_2) Avg Critical (6)  : 0.58 ± 0.014558 s.e.m. (p = 0.000213912, Wilcoxon) across subjects
# (cohort_2) Avg Critical (12) : 0.60 ± 0.012103 s.e.m. (p = 1.5099e-15, Wilcoxon) across subjects

# %%
# Plot behavioral patterns #
ti.Behavior_plot( p, Behaviors, TIDs_plot, titlestr = str, omit_individuals=True, SEM = True) # single model
# Out:
# /Users/kendrick/emergent_transitive/ti_functions.py:1340: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(YTICKLABELS)
# /Users/kendrick/emergent_transitive/ti_functions.py:1204: RuntimeWarning: Mean of empty slice
#   Y_MAX_RT_MAT    = np.ceil( np.nanmax(np.nanmean(Behavior['RTmat'][:,:,inds],axis=2).flatten()) )
# /Users/kendrick/emergent_transitive/ti_functions.py:1225: RuntimeWarning: Mean of empty slice
#   mat_all = np.nanmean(mat,axis=2)
# /Users/kendrick/emergent_transitive/ti_functions.py:1340: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(YTICKLABELS)
# Human Max RT: 522 milliseconds
# (p = 5.91904e-25, Wilcoxon) RT, end-order effect (signed rank), across subjects

# %%
# Plot End-order effect #
ti.Plot_End_Order_Human(p, Behaviors, TIDs_plot, str)

# %%
# Plot individual RTs #

Blocks_toplot   = np.array([4,5,6])   # early test
# Blocks_toplot   = np.array([1,2,3]) # training
# Blocks_toplot   = np.array([7,8,9]) # late test

ti.Plot_Human_Subject_End_Order_RT(Data, Behaviors, Blocks_toplot, TIDs_plot, str)  # plot individual RTs #

# %%
# Individual RTs, comparison #

Blocks_toplot   = np.array([4,5,6])   # early test
# Blocks_toplot   = np.array([1,2,3]) # training
# Blocks_toplot   = np.array([7,8,9]) # late test

ti.Report_End_Order_Stats(p, Data, Behaviors, Blocks_toplot, TIDs_plot, str)
# Out:
# End order index vs. 0 : p = 4.98663e-25
# PID: 10681, version: 1, p = 0.000387782
# PID: 11498, version: 1, p = 0.00831461
# PID: 12053, version: 1, p = 0.0555457
# PID: 12066, version: 1, p = 0.149449
# PID: 12772, version: 1, p = 3.0566e-05
# PID: 13066, version: 2, p = 0.254953
# PID: 13259, version: 2, p = 0.437641
# PID: 13622, version: 1, p = 0.293859
# PID: 13920, version: 2, p = 0.208871
# PID: 14025, version: 1, p = 0.625631
# PID: 14054, version: 2, p = 0.200949
# PID: 14944, version: 1, p = 4.7445e-06
# PID: 15337, version: 1, p = 0.00906876
# PID: 15801, version: 1, p = 0.882466
# PID: 16379, version: 1, p = 0.744986
# PID: 16895, version: 2, p = 0.464273
# PID: 17029, version: 2, p = 0.630876
# PID: 18045, version: 2, p = 0.0281287
# PID: 18641, version: 1, p = 1.33476e-06
# PID: 18765, version: 1, p = 0.115362
# PID: 18767, version: 2, p = 0.728265
# PID: 19295, version: 2, p = 0.468798
# PID: 19557, version: 2, p = 0.122353
# PID: 20867, version: 2, p = 0.340288
# PID: 21881, version: 1, p = 0.000158461
# PID: 22223, version: 1, p = 0.00532208
# PID: 22357, version: 2, p = 0.0877104
# PID: 22559, version: 2, p = 0.778784
# PID: 22656, version: 2, p = 0.790147
# PID: 22969, version: 2, p = 0.11708
# PID: 23103, version: 1, p = 7.22083e-06
# PID: 23673, version: 1, p = 2.12839e-09
# PID: 24308, version: 1, p = 0.0103147
# PID: 24925, version: 2, p = 0.311188
# PID: 25001, version: 2, p = 0.610008
# PID: 25827, version: 1, p = 1.12079e-09
# PID: 26806, version: 2, p = 0.403538
# PID: 27045, version: 1, p = 0.183321
# PID: 27050, version: 1, p = 0.946956
# PID: 27218, version: 1, p = 0.544408
# PID: 27953, version: 2, p = 0.905849
# PID: 28462, version: 2, p = 0.00190453
# PID: 28489, version: 2, p = 0.0724456
# PID: 28802, version: 1, p = 0.000318208
# PID: 29963, version: 1, p = 0.982307
# PID: 30014, version: 2, p = 0.0166169
# PID: 30030, version: 1, p = 0.143287
# PID: 30139, version: 2, p = 0.778784
# PID: 30294, version: 1, p = 0.000769729
# PID: 30433, version: 2, p = 0.141278
# PID: 30923, version: 1, p = 0.836024
# PID: 31030, version: 2, p = 0.952842
# PID: 31273, version: 1, p = 0.00172266
# PID: 31670, version: 1, p = 0.564215
# PID: 31968, version: 1, p = 2.67549e-07
# PID: 32085, version: 1, p = 0.000620265
# PID: 32229, version: 2, p = 0.428963
# PID: 32790, version: 2, p = 0.982307
# PID: 33002, version: 1, p = 7.31597e-07
# PID: 33213, version: 1, p = 0.000200581
# PID: 33215, version: 1, p = 0.007959
# PID: 33307, version: 1, p = 0.00496893
# PID: 33743, version: 1, p = 0.695215
# PID: 33771, version: 1, p = 0.193248
# PID: 34405, version: 2, p = 0.56922
# PID: 35180, version: 1, p = 0.0614519
# PID: 35526, version: 1, p = 0.442018
# PID: 35879, version: 1, p = 0.000571543
# PID: 36403, version: 1, p = 0.000387782
# PID: 36695, version: 1, p = 0.756201
# PID: 37124, version: 1, p = 0.917573
# PID: 37428, version: 1, p = 0.564215
# PID: 37850, version: 1, p = 0.248834
# PID: 38420, version: 1, p = 0.000410131
# PID: 38760, version: 2, p = 0.652044
# PID: 38804, version: 1, p = 1.80709e-05
# PID: 38887, version: 1, p = 0.836024
# PID: 38992, version: 1, p = 0.717189
# PID: 39684, version: 2, p = 0.23985
# PID: 39939, version: 1, p = 2.15403e-06
# PID: 40398, version: 1, p = 0.0962628
# PID: 40767, version: 1, p = 0.007959
# PID: 40847, version: 1, p = 0.176128
# PID: 40882, version: 1, p = 0.0187369
# PID: 41094, version: 2, p = 0.604839
# PID: 41119, version: 1, p = 0.717189
# PID: 41313, version: 1, p = 2.55151e-09
# PID: 41581, version: 2, p = 0.0398756
# PID: 41766, version: 1, p = 2.57212e-07
# PID: 41959, version: 1, p = 0.0286627
# PID: 42323, version: 2, p = 0.941072
# PID: 42523, version: 2, p = 0.0451462
# PID: 42716, version: 1, p = 0.505859
# PID: 42744, version: 1, p = 0.242819
# PID: 42781, version: 1, p = 0.0451462
# PID: 43436, version: 1, p = 0.153667
# PID: 43615, version: 1, p = 1.80709e-05
# PID: 44521, version: 1, p = 0.00103022
# PID: 44586, version: 1, p = 0.363222
# PID: 44674, version: 1, p = 8.86429e-09
# PID: 44755, version: 2, p = 0.559231
# PID: 45288, version: 2, p = 0.0198831
# PID: 45569, version: 1, p = 0.169146
# PID: 45682, version: 1, p = 1.06657e-07
# PID: 45707, version: 2, p = 0.589451
# PID: 45920, version: 1, p = 2.87195e-11
# PID: 46016, version: 1, p = 0.610008
# PID: 46084, version: 1, p = 0.982307
# PID: 46653, version: 1, p = 2.11048e-07
# PID: 46676, version: 2, p = 0.56922
# PID: 46958, version: 1, p = 0.3871
# PID: 46975, version: 2, p = 0.56922
# PID: 47393, version: 1, p = 0.000218931
# PID: 47542, version: 2, p = 0.51536
# PID: 47695, version: 2, p = 0.946956
# PID: 48171, version: 1, p = 0.160164
# PID: 48284, version: 2, p = 0.254953
# PID: 48643, version: 1, p = 0.000856412
# PID: 49696, version: 2, p = 0.529782
# PID: 50182, version: 2, p = 0.183321
# PID: 50879, version: 2, p = 0.242819
# PID: 51301, version: 1, p = 0.0260775
# PID: 51444, version: 1, p = 0.151547
# PID: 51720, version: 1, p = 2.00229e-06
# PID: 52211, version: 2, p = 0.599689
# PID: 52767, version: 1, p = 0.0443591
# PID: 53042, version: 1, p = 0.0604329
# PID: 53053, version: 2, p = 0.988204
# PID: 53056, version: 1, p = 0.379036
# PID: 53242, version: 2, p = 0.549327
# PID: 53586, version: 1, p = 1.59641e-07
# PID: 54068, version: 2, p = 0.668106
# PID: 54331, version: 2, p = 0.610008
# PID: 54334, version: 2, p = 0.340288
# PID: 55194, version: 1, p = 0.000927272
# PID: 55257, version: 1, p = 0.219782
# PID: 55668, version: 1, p = 8.01075e-06
# PID: 55766, version: 1, p = 0.0384692
# PID: 56233, version: 1, p = 1.66162e-07
# PID: 56941, version: 1, p = 0.00105755
# PID: 57117, version: 1, p = 0.314733
# PID: 57157, version: 2, p = 5.43359e-05
# PID: 57427, version: 2, p = 0.0223601
# PID: 58034, version: 1, p = 0.10869
# PID: 58351, version: 1, p = 2.98458e-06
# PID: 58420, version: 2, p = 0.145319
# PID: 58544, version: 1, p = 0.336558
# PID: 59137, version: 2, p = 0.72272
# PID: 59250, version: 1, p = 2.20424e-05
# PID: 59363, version: 2, p = 0.615196
# PID: 59701, version: 1, p = 0.0127321
# PID: 59996, version: 1, p = 0.630876
# PID: 60219, version: 2, p = 0.870811
# PID: 60540, version: 1, p = 6.35604e-05
# PID: 60727, version: 1, p = 0.367137
# PID: 61047, version: 1, p = 0.010097
# PID: 61102, version: 1, p = 0.976411
# PID: 61700, version: 1, p = 0.344045
# PID: 62724, version: 1, p = 0.0810611
# PID: 63123, version: 1, p = 0.77312
# PID: 63125, version: 2, p = 0.589451
# PID: 63397, version: 1, p = 0.510598
# PID: 63953, version: 1, p = 0.876635
# PID: 64375, version: 2, p = 0.0194944
# PID: 64597, version: 1, p = 0.00666888
# PID: 65015, version: 1, p = 0.00111426
# PID: 65136, version: 1, p = 0.756201
# PID: 65247, version: 1, p = 0.711673
# PID: 65491, version: 2, p = 0.78446
# PID: 65911, version: 2, p = 0.468798
# PID: 66339, version: 1, p = 0.143287
# PID: 66805, version: 1, p = 1.69313e-10
# PID: 66962, version: 1, p = 0.0594279
# PID: 66995, version: 1, p = 0.00067283
# PID: 67374, version: 1, p = 0.0536853
# PID: 67534, version: 1, p = 0.137323
# PID: 68235, version: 1, p = 0.1809
# PID: 68874, version: 2, p = 0.888303
# PID: 69078, version: 1, p = 0.0518771
# PID: 69579, version: 1, p = 0.00778635
# PID: 70073, version: 1, p = 0.0169549
# PID: 70128, version: 1, p = 0.137323
# PID: 70360, version: 2, p = 0.00463712
# PID: 70386, version: 1, p = 0.000100947
# PID: 70426, version: 1, p = 0.00289133
# PID: 70683, version: 1, p = 1
# PID: 70751, version: 2, p = 0.424662
# PID: 70772, version: 2, p = 0.982307
# PID: 71075, version: 2, p = 0.193248
# PID: 71384, version: 1, p = 0.0712784
# PID: 71531, version: 2, p = 0.17145
# PID: 71566, version: 1, p = 0.00108556
# PID: 71925, version: 2, p = 0.894146
# PID: 72045, version: 1, p = 0.383055
# PID: 72215, version: 2, p = 0.153667
# PID: 72773, version: 2, p = 4.4205e-06
# PID: 73092, version: 1, p = 0.00412843
# PID: 73662, version: 1, p = 6.16045e-05
# PID: 74888, version: 1, p = 0.000117472
# PID: 75328, version: 1, p = 0.0451462
# PID: 75474, version: 1, p = 0.018368
# PID: 75476, version: 1, p = 0.00147962
# PID: 75500, version: 1, p = 0.0241569
# PID: 75625, version: 2, p = 0.830255
# PID: 76028, version: 2, p = 0.23985
# PID: 76036, version: 1, p = 0.258051
# PID: 76158, version: 1, p = 2.27802e-05
# PID: 76179, version: 2, p = 0.689761
# PID: 76201, version: 2, p = 0.625631
# PID: 76385, version: 1, p = 0.000245857
# PID: 76447, version: 1, p = 0.08367
# PID: 76490, version: 2, p = 0.864994
# PID: 76643, version: 1, p = 1.25408e-07
# PID: 76997, version: 1, p = 4.9898e-07
# PID: 77256, version: 2, p = 0.946956
# PID: 77609, version: 1, p = 0.318304
# PID: 77862, version: 1, p = 8.1975e-07
# PID: 78216, version: 2, p = 0.65738
# PID: 78411, version: 1, p = 1.15665e-07
# PID: 78845, version: 1, p = 0.000100947
# PID: 78943, version: 1, p = 0.267503
# PID: 79301, version: 1, p = 0.0635327
# PID: 79601, version: 2, p = 0.23985
# PID: 79608, version: 1, p = 0.00172266
# PID: 79840, version: 2, p = 0.403538
# PID: 80480, version: 2, p = 1.20772e-05
# PID: 80992, version: 1, p = 0.00210389
# PID: 81064, version: 1, p = 0.0187369
# PID: 81080, version: 2, p = 0.795846
# PID: 81244, version: 1, p = 4.4205e-06
# PID: 82946, version: 1, p = 0.00108556
# PID: 82950, version: 1, p = 0.0420668
# PID: 83101, version: 2, p = 0.00596129
# PID: 83224, version: 1, p = 0.00172266
# PID: 83730, version: 2, p = 0.43329
# PID: 83965, version: 1, p = 5.43359e-05
# PID: 84383, version: 2, p = 0.813005
# PID: 85029, version: 1, p = 0.761828
# PID: 85054, version: 1, p = 4.35308e-05
# PID: 85328, version: 2, p = 0.970516
# PID: 86074, version: 1, p = 4.08395e-05
# PID: 86113, version: 1, p = 4.26655e-06
# PID: 86183, version: 1, p = 3.13058e-07
# PID: 86478, version: 1, p = 0.000769729
# PID: 86626, version: 2, p = 0.520145
# PID: 86668, version: 2, p = 0.982307
# PID: 87642, version: 1, p = 0.882466
# PID: 88363, version: 1, p = 0.000512112
# PID: 89572, version: 2, p = 0.529782
# PID: 90378, version: 2, p = 0.706171
# PID: 90802, version: 1, p = 0.321902
# PID: 91172, version: 1, p = 0.0509923
# PID: 91180, version: 1, p = 0.00200194
# PID: 91212, version: 1, p = 0.59456
# PID: 91251, version: 2, p = 0.245814
# PID: 91421, version: 1, p = 4.44405e-07
# PID: 91769, version: 1, p = 0.00666888
# PID: 92546, version: 1, p = 8.93338e-05
# PID: 92665, version: 2, p = 0.824496
# PID: 92678, version: 1, p = 3.87871e-11
# PID: 92816, version: 1, p = 0.000104066
# PID: 92891, version: 1, p = 0.321902
# PID: 93174, version: 1, p = 1.30573e-07
# PID: 93775, version: 2, p = 0.233989
# PID: 94208, version: 1, p = 0.0604329
# PID: 94222, version: 2, p = 0.399389
# PID: 95103, version: 1, p = 0.0712784
# PID: 95917, version: 1, p = 0.824496
# PID: 95922, version: 1, p = 1.20442e-07
# PID: 96009, version: 2, p = 0.39117
# PID: 96097, version: 1, p = 0.236907
# PID: 96492, version: 2, p = 0.982307
# PID: 96603, version: 1, p = 0.000445919
# PID: 96823, version: 1, p = 8.1975e-07
# PID: 96953, version: 1, p = 0.000366576
# PID: 97216, version: 2, p = 0.437641
# PID: 97586, version: 2, p = 0.0933408
# PID: 97805, version: 1, p = 0.00037704
# PID: 97954, version: 1, p = 0.000410131
# PID: 98207, version: 1, p = 0.304177
# PID: 98314, version: 2, p = 0.124151
# PID: 98330, version: 2, p = 0.0241569
# PID: 98388, version: 1, p = 1.43758e-06
# PID: 98409, version: 2, p = 0.77312
# PID: 98787, version: 1, p = 1.05414e-05
# PID: 98891, version: 1, p = 0.135378
# PID: 98899, version: 1, p = 0.952842
# PID: 98975, version: 1, p = 0.0320536
# PID: 99178, version: 2, p = 0.529782
# PID: 99492, version: 1, p = 0.0371053
# PID: 99651, version: 2, p = 0.137323
# PID: 99858, version: 2, p = 0.813005
# PID: 99925, version: 2, p = 0.51536
# PID: 99975, version: 1, p = 2.07683e-06
# 190 of 294 subjects (65%) show 1st-faster
# 104 of 294 subjects (35%) show 2nd-faster
# 92 of 190 1st-faster subjects (48%) are significant at 0.01 rank-sum
# 6 of 104 2nd-faster subjects (6%) are significant at 0.01 rank-sum

# %%
df = ti.Verbal_Report(p, Behaviors, Debrief, TIDs_plot)  # Debrief: 4th column is Choice strategy, 9th column is Learning strategy
